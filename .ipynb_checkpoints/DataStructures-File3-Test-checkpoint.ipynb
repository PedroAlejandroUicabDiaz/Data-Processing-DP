# %%
import pandas as pd

# %%
df = pd.read_csv("File3.csv")

# %%
df
# Out:
#    DataSet  Mean x  Variance x  Mean y  Variance y  Correlation  Slope  \
# 0        1     9.0        11.0    7.50       4.127       0.8164    0.5
# 1        2     9.0        11.0    7.50       4.128       0.8162    0.5
# 2        3     9.0        11.0    7.50       4.123       0.8163    0.5
# 3        4     9.0        11.0    7.49       4.135       0.8167    0.5
#
#    Intercept
# 0       3.00
# 1       3.00
# 2       3.00
# 3       2.99

# %%
df
# Out:
#    DataSet  Mean x  Variance x  Mean y  Variance y  Correlation  Slope  \
# 0        1     9.0        11.0    7.50        4.13         0.82    0.5
# 1        2     9.0        11.0    7.50        4.13         0.82    0.5
# 2        3     9.0        11.0    7.50        4.12         0.82    0.5
# 3        4     9.0        11.0    7.49        4.13         0.82    0.5
#
#    Intercept
# 0       3.00
# 1       3.00
# 2       3.00
# 3       2.99

# %%
# -1   ---- 11
df
# Out:
#    DataSet  Mean x  Variance x  Mean y  Variance y  Correlation  Slope  \
# 0        1     9.0        11.0    7.50        4.13         0.74    0.5
# 1        2     9.0        11.0    7.50        4.13         0.74    0.5
# 2        2     9.0        11.0    7.50        4.12         0.74    0.5
# 3        2     9.0        11.0    7.49        4.13         0.74    0.5
#
#    Intercept
# 0       3.00
# 1       3.00
# 2       3.00
# 3       2.99

# %%
# -2 ----- 10
df
# Out:
#    DataSet  Mean x  Variance x  Mean y  Variance y  Correlation  Slope  \
# 0        1     9.0        11.0    7.50        4.13         0.82  -0.92
# 1        2     9.0        11.0    7.50        4.13         0.82  -0.92
# 2        2     9.0        11.0    7.50        4.12         0.82  -0.92
# 3        2     9.0        11.0    7.49        4.13         0.82  -0.91
#
#    Intercept
# 0      15.79
# 1      15.79
# 2      15.80
# 3      15.72
